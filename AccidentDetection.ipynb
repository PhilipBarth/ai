# %%
import pandas as pd
from anytree import Node, RenderTree
from anytree.exporter import UniqueDotExporter, DotExporter

# %%
df = pd.read_csv("collisions.csv", low_memory=False)
#rename columns
df = df.rename(columns={'CRASH DATE' : 'Date', 'CRASH TIME' : 'Time', 'ON STREET NAME' : 'Street', 
                        'VEHICLE TYPE CODE 1' : 'Vehicle 1', 'VEHICLE TYPE CODE 2' : 'Vehicle 2',
                        'VEHICLE TYPE CODE 3' : 'Vehicle 3', 'VEHICLE TYPE CODE 4' : 'Vehicle 4',
                        'VEHICLE TYPE CODE 5' : 'Vehicle 5'})

##List of columns you want to keep
columns_to_keep = ['Date', 'Time', 'Street', 'Vehicle 1', 'Vehicle 2', 'Vehicle 3', 'Vehicle 4','Vehicle 5']
df = df[columns_to_keep]

# %%
root = Node("Root")

timeList = [("00:00","06:00"),("06:00","10:00"),("10:00","15:00"),("15:00","19:00"),("19:00","24:00")];

# %%
street_names_unique = df["Street"].unique()

# %%
street_names = street_names_unique[:1000]
print(street_names)

# Iterate over each unique street name
for street_name in street_names:
    street_node = Node(street_name, parent=root)
    
    # Subset the data for the current street name
    street_data = df[df["Street"] == street_name]
    
    # Segment the data by crash time
    crash_times = street_data["Time"].unique()
    
    for timeslot in timeList:
        timeslot_node = Node(timeslot, parent=street_node)
        
        local_crash_times = []
        
        for crash_time in crash_times:
            slot_hour_begin, slot_minute_begin = map(int, timeslot[0].split(':'))
            slot_hour_end, slot_minute_end = map(int, timeslot[1].split(':'))
            hour, minute = map(int, crash_time.split(':'))
            
            if slot_hour_begin <= hour < slot_hour_end:
                local_crash_times.append(crash_time)
    
        # Iterate over each unique crash time
        for crash_time in local_crash_times:
            crash_time_node = Node(crash_time, parent=timeslot_node)
        
            # Subset the data for the current crash time and street name
            crash_time_data = street_data[street_data["Time"] == crash_time]
        
            # Segment the data by vehicle types
            vehicle_types = crash_time_data[["Vehicle 1", "Vehicle 2"]].stack().unique()
        
            # Iterate over each unique vehicle type
            for vehicle_type in vehicle_types:
                vehicle_type_node = Node(vehicle_type, parent=crash_time_node)
# Out:
# ['WHITESTONE EXPRESSWAY' 'QUEENSBORO BRIDGE UPPER' 'THROGS NECK BRIDGE'
#  nan 'SARATOGA AVENUE' 'MAJOR DEEGAN EXPRESSWAY RAMP'
#  'BROOKLYN QUEENS EXPRESSWAY' '3 AVENUE' 'MYRTLE AVENUE'
#  'SPRINGFIELD BOULEVARD' 'broadway' 'BELT PARKWAY' 'NORTH CONDUIT AVENUE'
#  'MEEKER AVENUE' 'WEST KINGSBRIDGE ROAD' 'LONG ISLAND EXPRESSWAY'
#  '82 STREET' 'LEXINGTON AVENUE' 'VICTORY BOULEVARD' 'EAST 18 STREET'
#  'FULTON STREET' 'GRAND STREET' 'EAST 93 STREET' 'EASTCHESTER ROAD'
#  'KINGSLAND AVENUE' 'WILLIAMSBURG BRIDGE OUTER ROADWA'
#  'HUTCHINSON RIVER PARKWAY' 'ELIOT AVENUE' 'STATEN ISLAND EXPRESSWAY'
#  'BOSTON ROAD' 'EAST 107 STREET' 'BOSCOBEL PLACE' 'BRONX RIVER PARKWAY'
#  'EAST 162 STREET' 'CROSS BRONX EXPY' 'MAJOR DEEGAN EXPRESSWAY'
#  'WEST 56 STREET' 'AVENUE J' 'SAINT MARKS AVENUE' 'THROOP AVENUE'
#  'HENRY HUDSON PARKWAY' 'ROCKAWAY AVENUE' 'UTICA AVENUE' 'THOMSON AVENUE'
#  'VANWYCK EXPRESSWAY' '21 STREET' 'JAMAICA AVENUE' '1 AVENUE'
#  'BEACH CHANNEL DRIVE' 'EAST 7 STREET' 'WEST 177 STREET' '149 AVENUE'
#  'CROWN STREET' 'EAST END AVENUE' '12 AVENUE' 'TAYLOR STREET'
#  'WEST SHORE EXPRESSWAY' 'FLUSHING AVENUE' 'FLATBUSH AVENUE'
#  'OCEAN PARKWAY' 'CARROLL STREET' '23 STREET' 'AVENUE Y'
#  'SCHENECTADY AVENUE' '47 ROAD' 'KINGS HIGHWAY' 'CORSON AVENUE'
#  'WEST 101 STREET' 'QUEENS BOULEVARD' '115 AVENUE' '131 STREET'
#  'LACONIA AVENUE' 'WHITE PLAINS ROAD' 'MANHATTAN AVENUE' 'AVENUE N'
#  'BRUCKNER BOULEVARD' 'PROSPECT PLACE' 'WATSON AVENUE'
#  'FORT HAMILTON PARKWAY' 'EAST 94 STREET' '114 STREET' 'EAST 62 STREET'
#  'WEST 30 STREET' 'SAINT NICHOLAS AVENUE' '139 STREET'
#  'JACKIE ROBINSON EXPY' 'EAST 241 STREET' '47 STREET' 'GOWANUS RAMP'
#  'GRAND AVENUE' 'SUTTER AVENUE' 'ESSEX STREET' 'EAST 120 STREET'
#  'FDR DRIVE' 'EAST 168 STREET' 'GRAND CONCOURSE' 'GULF AVENUE'
#  'WEST FORDHAM ROAD' '65 STREET' 'GERRITSEN AVENUE' 'MADISON STREET'
#  '49 street' 'BUSHWICK AVENUE' 'NOSTRAND AVENUE' 'JEROME AVENUE'
#  'VANDERVORT AVENUE' 'VERRAZANO BRIDGE' 'ROCKAWAY BOULEVARD'
#  'UNION STREET' 'PORT RICHMOND AVENUE' 'MCCLEAN AVENUE'
#  'PARSONS BOULEVARD' 'MARCY AVENUE' '179 STREET' 'WEST 76 STREET'
#  'AVENUE OF THE AMERICAS' 'LEONARD AVENUE' 'WASHINGTON SQUARE NORTH'
#  'CONEY ISLAND AVENUE' 'CROSS ISLAND PARKWAY' 'EASTERN PARKWAY'
#  'WEST 38 STREET' 'EAST FORDHAM ROAD' 'CENTRAL AVENUE' 'WEST 84 STREET'
#  '70 STREET' '39 AVENUE' 'AVENUE U' 'SAINT JOHNS AVENUE' 'GRAHAM AVENUE'
#  'WETHEROLE STREET' 'EAST 188 STREET' 'BURKE AVENUE' '130 AVENUE'
#  'CALAMUS AVENUE' 'WEST 51 STREET' 'GEORGIA AVENUE' 'WEST STREET'
#  'BERGEN STREET' 'FRANKLIN AVENUE' '13 STREET' 'GLENWOOD ROAD'
#  'VERRAZANO BRIDGE UPPER' 'CHAMBERS STREET' 'BROADWAY' 'BOYNTON PLACE'
#  'ITTNER PLACE' 'LEROY STREET' 'BRUCKNER EXPRESSWAY' '135 PLACE'
#  'CLINTON STREET' '7 AVENUE' 'GREENE AVENUE' 'WEST 181 STREET'
#  'LIBERTY AVENUE' 'ROME AVENUE' 'VAN WYCK EXPWY' 'EAST 167 STREET'
#  'CLAWSON STREET' '33 st' '74 STREET' 'SUTPHIN BOULEVARD'
#  'BRIGHTON BEACH AVENUE' 'WEST 120 STREET' 'OGDEN AVENUE' '222 STREET'
#  'ATLANTIC AVENUE' 'HALLECK STREET' 'BRONX BOULEVARD' 'GRAND CENTRAL PKWY'
#  'CROSS BRONX EXPY RAMP' 'WEST 147 STREET' 'TILDEN AVENUE'
#  'ROCKAWAY PARKWAY' 'JEFFERSON AVENUE' 'TARGEE STREET' 'NEVINS STREET'
#  '72 STREET' '18 AVENUE' '86 STREET' '146 STREET' 'ELTON STREET'
#  'DUNLOP AVENUE' 'AVENUE P' '62 STREET' 'WEST GUN HILL ROAD'
#  'UNION TURNPIKE' 'FRANKLIN STREET' 'LINDEN BOULEVARD' 'EAST 22 STREET'
#  'DEERFIELD ROAD' 'HAMILTON AVENUE' 'HASTINGS STREET' '105 AVENUE'
#  'JEFFERSON STREET' 'SHEPHERD AVENUE' 'BRADLEY AVENUE' 'BEDFORD AVENUE'
#  'ROOSEVELT AVENUE' 'BAISLEY BOULEVARD' 'BRONX RIVER PARKWAY RAMP'
#  'CLEARVIEW EXPRESSWAY' 'RICHMOND AVENUE' 'ARNOW PLACE'
#  'BAY RIDGE PARKWAY' 'WEST 140 STREET' 'GRAND CENTRAL PARKWAY'
#  'EAST 179 STREET' 'EDGEMERE AVENUE' 'VERRAZANO BRIDGE LOWER'
#  'BEACH 9 STREET' 'HENRY HUDSON PARKWAY RAMP' 'BROOKVILLE BOULEVARD'
#  'EAST 16 STREET' 'SOUND VIEW AVENUE' 'WEST 33 STREET'
#  'JACKIE ROBINSON PKWY' 'DELANCEY STREET' 'EAST 194 STREET'
#  'EAST HOUSTON STREET' 'EAST 111 STREET' 'LAYTON AVENUE' 'SURF AVENUE'
#  'PITKIN AVENUE' 'SAINT CLAIR PLACE' '108 AVENUE' '93 STREET' '5 AVENUE'
#  'RIDGEWOOD AVENUE' 'EAST 70 STREET' 'BEACH 17 STREET' '28 STREET'
#  'BREWER BOULEVARD' 'JACKSON AVENUE' '114 DRIVE' 'SHEFFIELD AVENUE'
#  'DE KALB AVENUE' 'SOUTH CONDUIT AVENUE' 'NEW ENGLAND THRUWAY'
#  '143 STREET' 'MERRICK BOULEVARD' 'GARRETSON AVENUE' 'FOREST AVENUE'
#  'EAST 105 STREET' 'GOLD STREET' 'BRUCKNER BLVD' 'COURT STREET'
#  'RALPH AVENUE' 'BARCLAY AVENUE' 'GARRISON AVENUE' 'HUGUENOT AVENUE'
#  'WEST 94 STREET' 'PRINCE STREET' 'EAST 19 STREET' '203 STREET'
#  'GOWANUS EXPY (BQE)' 'HOWARD AVENUE' 'EAST TREMONT AVENUE'
#  'HAVEMEYER STREET' 'BELL BOULEVARD' '73 AVENUE' '140 AVENUE'
#  'WEST 35 STREET' '24 STREET' 'ARMSTRONG AVENUE' 'CLINTONVILLE STREET'
#  'METROPOLITAN AVENUE' 'WEST 180 STREET' 'GERARD AVENUE' 'STORY STREET'
#  'COOPER AVENUE' 'MURDOCK AVENUE' 'ARLINGTON PLACE' 'WEST 42 STREET'
#  '2 AVENUE' 'EAST 66 STREET' 'WEST 8 STREET' 'EDISON STREET'
#  'RIVER AVENUE' 'BATH AVENUE' 'LENOX AVENUE' 'STEWART AVENUE'
#  'FOSTER AVENUE' 'NORWAY AVENUE' 'WEST 122 STREET' 'EAST 42 STREET'
#  '30 STREET' 'WEST 29 STREET' 'DAVIDSON AVENUE' 'EAST 57 STREET'
#  'MC DONALD AVENUE' 'AMBOY ROAD' 'WASHINGTON AVENUE' 'PARSONS BLVD'
#  'EAST 209 STREET' 'SOUTHERN BOULEVARD' 'HEGEMAN AVENUE' 'DUMONT AVENUE'
#  'GRANT HIGHWAY' '111 AVENUE' '51 AVENUE' 'FLATBUSH AVENUE EXTENSION'
#  '201 STREET' '4 AVENUE' '16 AVENUE' 'ALDUS STREET' 'TINTON AVENUE'
#  'COZINE AVENUE' 'PERRY AVENUE' 'SAINT JOHNS PLACE' '41 STREET'
#  'Trans- Manhattan Expressway' 'EAST 80 STREET' 'TOMPKINS AVENUE'
#  'WEST END AVENUE' 'BROOK AVENUE' '241 STREET' 'EAST 115 STREET'
#  'VANDAM STREET' 'AMSTERDAM AVENUE' '218 STREET' 'REVIEW AVENUE'
#  'AVENUE M' 'HUGHES AVENUE' 'MONTROSE AVENUE' 'EAST 183 STREET'
#  'ARCHER AVENUE' 'EAST 233 STREET' '102 ROAD' 'WADSWORTH AVENUE'
#  'ROEBLING STREET' 'EAST 90 STREET' '263 STREET' 'AVENUE F' '14 AVENUE'
#  'WILLIAMSBURG STREET WEST' 'EAST 125 STREET' 'WEST 48 STREET'
#  'EAST 193 STREET' 'MERMAID AVENUE' '85 STREET' '51 STREET'
#  'BENSON AVENUE' 'HARLEM RIVER DRIVE' 'PAYSON AVENUE' 'HYLAN BOULEVARD'
#  'NEW DORP LANE' 'SUYDAM PLACE' 'EAST 26 STREET' '8 AVENUE' '37 AVENUE'
#  'EAST 20 STREET' 'WEST 32 STREET' 'RIVERDALE AVENUE'
#  'G.C.P. / JEWEL (CDR)/2020' 'FOOTHILL AVENUE' '120 STREET' '45 AVENUE'
#  'BARTOW AVENUE' 'MAURICE AVENUE' 'MENAHAN STREET' 'BLAKE AVENUE'
#  'CHAUNCEY STREET' 'NORTHERN BOULEVARD' 'PARK AVENUE' 'EAST 206 STREET'
#  'WOODHAVEN BOULEVARD' 'CHURCH AVENUE' 'STUYVESANT AVENUE'
#  'EAST GUN HILL ROAD' 'COLUMBUS AVENUE' 'BRONX WHITESTONE BRIDGE'
#  'NEWPORT STREET' '38 AVENUE' 'TELLER AVENUE' 'ATTORNEY STREET'
#  'Beadle Street' 'UNDERCLIFF AVENUE' 'EAST 184 STREET' 'EAST 128 STREET'
#  'LENOX ROAD' '155 STREET' 'FRANCIS LEWIS BOULEVARD' 'WEST 79 STREET'
#  'SILVER STREET' '144 STREET' 'GREENPOINT AVENUE' 'STONE AVENUE'
#  'SHORE PARKWAY' 'WEST 135 STREET' 'WEBB AVENUE' '39 STREET'
#  'EAST 135 STREET' 'JUNIUS STREET' 'FRESH POND ROAD' 'EAST 53 STREET'
#  'CRESCENT STREET' 'BEVERLEY ROAD' 'ALLERTON AVENUE' 'TROY AVENUE'
#  'EAST 37 STREET' 'WILLOW AVENUE' 'EAST 98 STREET' 'NEW LOTS AVENUE'
#  '171 STREET' '43 STREET' 'ARLENE COURT' 'BROOKLYN BATTERY TUNNEL'
#  'LEONARD STREET' '91 AVENUE' 'WEST 17 STREET' '54 AVENUE'
#  'LINCOLN AVENUE' '38 STREET' 'TRIBOROUGH BRIDGE' 'PUTNAM AVENUE'
#  'WEBSTER AVENUE' 'Leonard street' '122 AVENUE' '73 PLACE'
#  'INGRAHAM STREET' 'QUEENS PLAZA NORTH' '118 AVENUE' 'WEST 125 STREET'
#  'GERALD COURT' '119 AVENUE' 'WILLIAMSBRIDGE ROAD' 'SHERMAN AVENUE'
#  'RICHMOND ROAD' 'AVENUE D' 'EAST 96 STREET' '23 AVENUE' 'REMSEN AVENUE'
#  '87 STREET' 'PENNSYLVANIA AVENUE' 'SAINT ANNS AVENUE' 'WATERBURY STREET'
#  '150 STREET' 'BAY PARKWAY' 'ELY AVENUE' 'BELMONT AVENUE' 'FARRAGUT ROAD'
#  'KINGSTON PLACE' 'NORFOLK STREET' 'NEPTUNE AVENUE' 'DEWEY PLACE'
#  'OSBORNE AVENUE' 'FOREST PARK DRIVE' 'ROCKAWAY BEACH BOULEVARD'
#  'BAINBRIDGE AVENUE' 'PELHAM PARKWAY' 'ULMER STREET' 'CATON AVENUE'
#  'FORSYTH STREET' 'UNIVERSITY AVENUE' 'MADISON AVENUE'
#  'LEFFERTS BOULEVARD' '80 STREET' 'KNICKERBOCKER AVENUE' 'WEST 64 STREET'
#  'GREENFIELD AVENUE' 'EAST 13 STREET' 'MARION AVENUE' 'WEST 34 STREET'
#  'HENDRIX STREET' 'EAST 64 STREET' 'WEST 155 STREET' 'WINCHESTER AVENUE'
#  'EAST 119 STREET' 'BOYLAND STREET' 'WOLCOTT STREET' 'CORAL REEF WAY'
#  'WEST 95 STREET' 'EAST 88 STREET' 'EAST 46 STREET' 'EAST NEW YORK AVENUE'
#  '30 AVENUE' 'HART PLACE' 'ROGERS AVENUE' '31 AVENUE' 'RANDALL AVENUE'
#  'COMMONWEALTH BOULEVARD' 'CLIFFORD PLACE' 'DEAN STREET' '149 STREET'
#  'EAST 161 STREET' 'EAST 106 STREET' '230 STREET' 'EAST 169 STREET'
#  'WEST 130 STREET' 'EAST 35 STREET' 'EAST 147 STREET' 'SMITH STREET'
#  'MIDDLETON STREET' '49 AVENUE' '164 STREET' 'SEDGWICK AVENUE'
#  'STILLWELL AVENUE' '249 STREET' 'ROCHESTER AVENUE' 'HICKS STREET'
#  '381A Marcus Garvey Blvd' 'EAST 158 STREET' 'NOME AVENUE'
#  'PARKSIDE AVENUE' 'WINTHROP STREET' 'CHRISTOPHER LANE' '48 AVENUE'
#  '90 AVENUE' 'EAST 84 STREET' 'WEST 169 STREET' 'MACOMBS ROAD'
#  'COHANCY STREET' 'LORIMER STREET' 'WEST 47 STREET' 'WEST 133 STREET'
#  'pennsylvania ave' '231 STREET' 'WATER STREET' '116 AVENUE' '55 STREET'
#  '67 AVENUE' 'WEST 44 STREET' 'OVERLOOK TERRACE' 'DEKALB AVENUE'
#  'NEW STREET' 'GLENMORE AVENUE' '181 PLACE' 'ONEIDA AVENUE'
#  'HORACE HARDING EXPRESSWAY' 'WALTON AVENUE' 'LEE AVENUE'
#  'EAST 174 STREET' '69 AVENUE' 'ALBANY AVENUE' '68 ROAD' 'SHORE BOULEVARD'
#  'BAY STREET' 'CORNELIA STREET' 'DOWNING STREET' '83 STREET'
#  'TIFFANY STREET' 'MELROSE AVENUE' 'BRONX PARK EAST' 'WEST 20 STREET'
#  '32 AVENUE' '153 COURT' '88 ROAD' 'JAY STREET' 'QUEENS PLAZA SOUTH'
#  'MORRIS PARK AVENUE' 'VANCLEEF STREET' 'KNAPP STREET' '97 AVENUE'
#  'EARHART LANE' 'WEST 103 STREET' 'PULASKI BRIDGE' 'SAINT PATRICK PLACE'
#  'NORTH 6 STREET' 'NELSON AVENUE' 'ARTHUR KILL ROAD' 'IRVING AVENUE'
#  'CHRYSTIE STREET' 'EAST 176 STREET' 'STANHOPE STREET' 'ELDERT STREET'
#  'TILLARY STREET' 'CEDAR AVENUE' '105 STREET' 'VANDUZER STREET'
#  '81 STREET' 'EAST 67 STREET' 'ROCKAWAY FREEWAY' 'KENT AVENUE'
#  'WEST 93 STREET' 'ROSEDALE AVENUE' 'EAST 138 STREET' 'OVINGTON AVENUE'
#  '219 STREET' 'HEMPSTEAD AVENUE' 'SEAGIRT BOULEVARD' 'VETERANS ROAD EAST'
#  'EMPIRE BOULEVARD' 'EAST 149 STREET' 'AVENUE Z' 'WEST 126 STREET'
#  '50 AVENUE' 'BELKNAP STREET' '10 AVENUE' 'PEARL STREET' 'WARWICK STREET'
#  'BELT PARKWAY RAMP' 'BAYCHESTER AVENUE' 'EAST 36 STREET' 'HESTER STREET'
#  'CLAY AVENUE' 'CORNAGA AVENUE' 'UNION AVENUE' '140 STREET'
#  'FOUNTAIN AVENUE' 'LONGWOOD AVENUE' 'STOCKHOLM STREET' '42 street'
#  'BROOKLYN BRIDGE' 'COLLEGE POINT BOULEVARD' 'EAST 10 STREET'
#  'WEST 66 STREET' 'east new york ave' 'JEWEL AVENUE' 'MURRAY STREET'
#  'ASTORIA BOULEVARD' 'EAST 54 STREET' 'EAST 48 STREET' 'CANAL STREET'
#  'NEW HAVEN AVENUE' 'EAST 211 STREET' 'RUTLEDGE STREET' 'BOWNE STREET'
#  'REEVES AVENUE' 'NARROWS ROAD NORTH' 'EMMONS AVENUE' 'WEST 46 STREET'
#  'BRIGHTON 4 STREET' 'FILLMORE AVENUE' 'MACE AVENUE' 'WEST 71 STREET'
#  'UNDERHILL AVENUE' 'GOETHALS ROAD NORTH' 'HUNTER STREET' 'DYER AVENUE'
#  '128 STREET' '60 AVENUE' 'WEST 163 STREET' 'DECATUR AVENUE'
#  'ELIZABETH STREET' 'EAST 59 STREET' 'WEST 49 STREET' 'BORDEN AVENUE'
#  '48 STREET' 'FOREST HILL ROAD' 'MARCUS GARVEY BOULEVARD' 'EAST 51 STREET'
#  'Belt parkway' '111 STREET' 'MAIN STREET' 'WEST 43 STREET' 'HART STREET'
#  'CROSS BAY BOULEVARD' '108 STREET' 'HILLSIDE AVENUE' 'MORRIS AVENUE'
#  'WEST 96 STREET' 'PELHAM PARKWAY SOUTH' '11 AVENUE' 'WYTHE AVENUE'
#  'STORY AVENUE' '101 AVENUE' '68 STREET' '166 STREET' 'WEST 28 STREET'
#  'VIRGINIA AVENUE' 'BRIGHTON 3 STREET' 'WEST 151 STREET' 'EAST 56 STREET'
#  '75 AVENUE' 'MOSHOLU PARKWAY' 'WEST 207 STREET' 'TREADWELL AVENUE'
#  'COVERT STREET' 'EAST 163 STREET' 'WEST 176 STREET' '193 STREET'
#  'BROOKLYN AVENUE' '207 STREET' 'YORK AVENUE' 'GIVAN AVENUE' '34 STREET'
#  'WEST 50 STREET' 'EAST 17 STREET' 'HANCOCK STREET' 'WEST 145 STREET'
#  '192 STREET' 'HUDSON YARDS' 'SOUTH AVENUE' 'WEST 148 STREET' '84 AVENUE'
#  'OCCIDENT AVENUE' '47 AVENUE' '9 AVENUE' 'HANNIBAL STREET'
#  'G.C.P. / L.I.E (CDR)/2020' 'MONROE AVENUE' 'AVENUE I' 'DITMARS STREET'
#  '60 STREET' '133 AVENUE' 'AUDUBON AVENUE' '34 AVENUE' 'EAST BAY AVENUE'
#  'EAST 172 STREET' 'ROMA AVENUE' 'SNYDER AVENUE' 'MACOMBS PLACE' '69 LANE'
#  '106 AVENUE' 'STERLING PLACE' 'WILLOUGHBY AVENUE' 'NORTH HENRY STREET'
#  '97 STREET' 'WOOLLEY AVENUE' '42 STREET' 'PROSPECT AVENUE' '76 STREET'
#  '29 AVENUE' 'WEST 23 STREET' '104 AVENUE' '196 STREET' 'WEST 58 STREET'
#  'LAUREL HILL TERRACE' 'WEST 149 STREET' 'EAST 23 STREET' 'WEST 67 STREET'
#  'VAN SICLEN AVENUE' 'PACIFIC STREET' '139 AVENUE' 'Stickball Boulevard'
#  '160 AVENUE' 'NEW UTRECHT AVENUE' 'EAST 32 STREET' 'NATIONAL STREET'
#  'QUEENSBORO BRIDGE LOWER' 'FARMERS BOULEVARD' 'ANTHONY AVENUE'
#  'BARNES AVENUE' 'EAST 58 STREET' 'EAST 121 STREET' 'CROPSEY AVENUE'
#  'FAHY AVENUE' '35 AVENUE' '7 AVENUE SOUTH' 'HIMROD STREET'
#  'ALBEMARLE ROAD' '100 STREET' 'PARK LANE SOUTH' 'CATHERINE SLIP'
#  'DRUMGOOLE ROAD EAST' 'HOOK CREEK BOULEVARD' 'EAST 166 STREET'
#  '244 STREET' 'JERSEY STREET' 'MIDDLETOWN ROAD' 'NEW DORP PLAZA NORTH'
#  'WESTCHESTER AVENUE' 'BAY 11 STREET' 'EAST 87 STREET' 'CARLTON AVENUE'
#  '46 STREET' 'WESTMINISTER ROAD' 'RODNEY STREET' '75 ROAD' 'LEWIS AVENUE'
#  'WEST 25 STREET' 'RUTLAND ROAD' '169 STREET' 'NEWBOLD AVENUE'
#  'MACOMBS DAM BRIDGE' 'WEST 65 STREET' 'LOGAN STREET' 'EAST 34 STREET'
#  'HAVEN AVENUE' 'THROGS NECK EXPY' 'KENNEDY STREET' 'NORTH GANNON AVENUE'
#  'FORT WASHINGTON AVENUE' 'WEST 82 STREET' 'CROSS BRONX EXPRESSWAY'
#  '6 STREET' '61 STREET' 'BRONX RIVER AVENUE' 'LIE LOWER LEVEL (CDR)'
#  'HUTCHINSON RIVER PARKWAY RAMP' 'SHERIDAN AVENUE' 'CADMAN PLAZA WEST'
#  'MARGINAL STREET' 'DUPONT STREET' 'EAST 235 STREET' 'LIVONIA AVENUE'
#  'HAMPTON AVENUE' 'HEATH AVENUE' 'QUEENSBORO BRIDGE' 'WEST 146 STREET'
#  'DIX AVENUE' 'LAKE AVENUE' 'HOFFMAN STREET' 'OAK AVENUE' 'WILSON AVENUE'
#  'EAST 165 STREET' 'ERSKINE STREET' 'BROOKLYN QUEENS EXPRESSWAY RAMP'
#  'LAURELTON PARKWAY' 'JORDAN AVENUE' 'RYER AVENUE' 'WEST 137 STREET'
#  'BELT PARKWAY WESTBOUND' 'GREENWICH AVENUE' 'ARNOW AVENUE'
#  'SAINT NICHOLAS PLACE' 'ALABAMA AVENUE' 'MORGAN AVENUE' '95 AVENUE'
#  'ALEXANDER AVENUE' 'SUNRISE HIGHWAY' 'WEST 168 STREET'
#  'CENTRAL PARK WEST' 'CLARENDON ROAD' 'CLOVERDALE BOULEVARD' '148 DRIVE'
#  'CHATHAM SQUARE' 'EAST 181 STREET' 'CONCORD AVENUE' 'PAUL AVENUE'
#  'NEW YORK AVENUE' 'WEST 195 STREET' 'EAST 108 STREET' 'TIBBETT AVENUE'
#  'OCEAN AVENUE' 'EAST 187 STREET' '11 STREET' 'Duane road' 'AVENUE S'
#  'HUNTERS POINT AVENUE' 'MOUNT EDEN PARKWAY' 'ZEREGA AVENUE'
#  'PERRY STREET' '19 STREET' 'SHORE FRONT PARKWAY' 'MC CLANCY PLACE'
#  'POPHAM AVENUE' 'HARWAY AVENUE' 'IRWIN STREET' '64 STREET'
#  'CROTONA AVENUE' 'WEST 158 STREET' 'WEST 24 STREET' 'POWERS STREET'
#  'Cypress avenue' 'BRIGHTON 1 STREET' 'SELWYN AVENUE' '31 STREET'
#  '107 STREET' 'PROSPECT PARK SOUTHWEST' 'FORT GEORGE HILL' 'HOLLIS AVENUE'
#  'WEST 13 STREET' 'DITMARS BOULEVARD' 'DUNKIRK DRIVE' '154 STREET'
#  'EAST 5 STREET' 'MANOR ROAD' 'RICHMOND TERRACE' 'FLATLANDS AVENUE'
#  'LIE OUTER ROADWAY (CDR)' '119 STREET' 'BOWERY' '45 STREET' '58 STREET'
#  'KALMIA AVENUE' '163 STREET' '56 STREET' '23 ROAD' 'WEST 132 STREET'
#  '26 AVENUE' 'VAN SINDEREN AVENUE' 'EAST 228 STREET' 'FORLEY STREET'
#  'VANDERBILT AVENUE' 'JUNIPER VALLEY ROAD' 'AVENUE X' 'LOTT AVENUE'
#  'LINDEN STREET' '124 STREET' 'HIGHLAND BOULEVARD' 'QUINCY AVENUE'
#  'EAST 61 STREET' '66 STREET' '256 STREET' 'EAST 4 STREET'
#  'WALLABOUT STREET' 'WEST 134 STREET' 'SHERIDAN EXPRESSWAY'
#  'Stadium place S' 'WEST 6 STREET' '17 STREET' 'COLUMBUS CIRCLE'
#  'SAINT NICHOLAS TERRACE' 'EAST 155 STREET' 'WEST 230 STREET'
#  'SUFFOLK STREET' 'EAST 14 STREET' '107 AVENUE' 'CLARKSON AVENUE'
#  'KELLY BOULEVARD' 'OLINVILLE AVENUE' '86 AVENUE' 'MONROE STREET'
#  'W/B MARINA ROAD/2020' '125 STREET' 'EAST 25 STREET' '159 STREET'
#  'KINGSTON AVENUE' '141 STREET' 'MOORE STREET' 'CORTELYOU ROAD'
#  'ARTHUR AVENUE' 'WEST 141 STREET' 'CYPRESS AVENUE' 'WESTERVELT AVENUE'
#  'WEST 22 STREET' 'BAXTER AVENUE' 'SNEDIKER AVENUE'
#  'EAST MOSHOLU PARKWAY NORTH' 'LONG STREET' 'WEST 55 STREET'
#  'FDR DRIVE RAMP' 'WEST 136 STREET' 'EDENWALD AVENUE' 'MAPLE AVENUE'
#  'GOBLE PLACE' '72 PLACE' 'EAST 116 STREET' 'PROSPECT EXPRESSWAY RAMP'
#  'EAST 97 STREET' '112 STREET' 'POWELL STREET' 'PARK CIRCLE' '21 AVENUE'
#  'ZULETTE AVENUE' 'EAST 134 STREET' '84 STREET' 'WEST 150 STREET'
#  'VANCORTLANDT AVENUE EAST' 'RIVERSIDE DRIVE' 'EAST 102 STREET'
#  '79 STREET' 'EAST 92 STREET' 'EAST 180 STREET' 'THROGS NECK EXPRESSWAY'
#  '42 ROAD' 'LITTLE NECK PARKWAY' 'CHURCH STREET' 'EAST 232 STREET'
#  '33 ROAD' 'CLOVE ROAD' 'CLARKE AVENUE' 'DUFFIELD STREET'
#  'UNIVERSITY HEIGHTS BRIDGE' 'PARK AVENUE SOUTH' 'SIDWAY PLACE'
#  '20 AVENUE' '56 DRIVE' 'WHITLOCK AVENUE' 'DOUGLASTON PARKWAY' '6 AVENUE'
#  '32 PLACE' 'MAIDEN LANE' '43 AVENUE' 'HIGHLAND AVENUE' 'GATES AVENUE'
#  'WASHINGTON BRIDGE 181 ST' '120 AVENUE' 'WAKEMAN PLACE' 'WEST 5 STREET'
#  'VERNON BOULEVARD' 'NICK LAPORTE PLACE' 'FEATHERBED LANE'
#  'BOOTH MEMORIAL AVENUE' '41 AVENUE' 'WEST 87 STREET' 'MC KEEVER PLACE'
#  'VANWYCK EXPRESSWAY EXTENSION' 'LAIGHT STREET' 'MANHATTAN BR LOWER'
#  'EAST 95 STREET' '121 AVENUE' '92 STREET' '146 PLACE' 'WEST 45 STREET'
#  '271 STREET' 'EAST 31 STREET' 'WILKINSON AVENUE' 'STRANG AVENUE'
#  'BOYNTON AVENUE' 'AVENUE T' 'BRUSH AVENUE' 'KISSENA BOULEVARD'
#  'WEST 89 STREET' '98 STREET' 'WEST 97 STREET' 'EAST 91 STREET'
#  'LIVINGSTON STREET']

# %%
def get_descendants_count(node):
    count = len(node.children)
    for child in node.children:
        count += get_descendants_count(child)
    return count

def update_node_names(node):
    count = get_descendants_count(node)
    node.name = f"{node.name} ({count})"
    for child in node.children:
        update_node_names(child)


##for pre, _, node in RenderTree(root):
##    count = len(node.children)
##    node.name = f"{node.name} ({count})"
    
update_node_names(root)

# %%
# Print tree to visualize
#for pre, fill, node in RenderTree(root):
#    print(f"{pre}{node.name}")

# %%
#Export tree to .dot File and into image(not working well with huge trees)
#UniqueDotExporter(root, maxlevel=3).to_picture("accidents.png")
DotExporter(root).to_dotfile("accidents.dot")
DotExporter(root).to_dotfile("accidentsFile.txt")

# %%
# Eingabe der aktuellen Straße

inputStreetName = input("Enter Street Name:")
# Out:
# Enter Street Name:BROADWAY

# %%
selectedNode = root;

for node in root.children:
    if inputStreetName in node.name and selectedNode == root:
        selectedNode = node;

print("Gefundene Straße:" + selectedNode.name)
# Out:
# Gefundene Straße:BROADWAY (3653)

# %%
time = "null"        

# Eingabe der aktuellen Uhrzeit

if selectedNode != root:        
    time = input("Uhrzeit :")

# Ermitteln des passenden Zeitslots:

fittingTimeslot = ("null","null")

hour, minute = map(int, time.split(':'))

for timeSlot in timeList:
    slot_hour_begin, slot_minute_begin = map(int, timeSlot[0].split(':'))
    slot_hour_end, slot_minute_end = map(int, timeSlot[1].split(':'))
    if slot_hour_begin < hour <= slot_hour_end and fittingTimeslot == ("null","null"):
        fittingTimeslot = timeSlot
        
print("Gewählter Zeitslot:" + fittingTimeslot[0]+"-"+fittingTimeslot[1])    
timeNode = root

if time != "null":
    for node in selectedNode.children:
        if fittingTimeslot[0] in node.name and fittingTimeslot[1] in node.name and timeNode == root:
            timeNode = node
            
print(timeNode)
print(timeNode.children)
# Out:
# Uhrzeit :05:55
# Gewählter Zeitslot:00:00-06:00
# Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)")
# (Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/E-Bike (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Station Wagon/Sport Utility Vehicle/2020 (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Box Truck (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Sedan (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Station Wagon/Sport Utility Vehicle/2020 (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Sedan (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Sedan (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Station Wagon/Sport Utility Vehicle/2020 (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Taxi (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Station Wagon/Sport Utility Vehicle/2020 (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Sedan (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Bike (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Taxi (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Sedan (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Station Wagon/Sport Utility Vehicle/2020 (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Sedan (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Sedan (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Station Wagon/Sport Utility Vehicle/2020 (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Station Wagon/Sport Utility Vehicle/2020 (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/E-Bike (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Sedan (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Bus (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Station Wagon/Sport Utility Vehicle/2020 (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Sedan (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Tractor Truck Diesel (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Station Wagon/Sport Utility Vehicle/2020 (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Sedan (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Sedan (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Open Body (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Station Wagon/Sport Utility Vehicle/2020 (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/E-Bike (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Motorcycle (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Taxi (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Sedan (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/E-Bike (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Sedan (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Station Wagon/Sport Utility Vehicle/2020 (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Sedan (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Station Wagon/Sport Utility Vehicle/2020 (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Sedan (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Sedan (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Station Wagon/Sport Utility Vehicle/2020 (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Taxi (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Sedan (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Station Wagon/Sport Utility Vehicle/2020 (1)"), Node("/Root (287570)/BROADWAY (3653)/('00:00', '06:00') (544)/Taxi (1)"), Node("/Root (287570)/BROADWAY (3653 ...

# %%
# Ausrechnen der Gefahr:
if timeNode == root:
    print("Es ist ein Fehler aufgetreten, bitte versuche es erneut!")

# %%
if len(timeNode.children) == 0:
    print("Es besteht eine sehr geringe Gefahr!")

    #TODO: Change some thing
#if len(timeNode.children) > 0:
#    vehicleTypeHighest = timeNode.children[0];
#    for node in timeNode.children:
#        if len(node.children) > len(vehicleTypeHighest.children):
#            vehicleTypeHighest = node

#    print("Das höchste Risiko besteht mit folgendem Fahrzeugtypen:" , vehicleTypeHighest.name)
# Out:
# Das höchste Risiko besteht mit folgendem Fahrzeugtypen: E-Bike (1)
